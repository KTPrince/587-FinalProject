# %%
#!pip install yfinance
#!pip install requests
#!pip install beautifulsoup4

# %%
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

#We only care about data from the last two months
end_date = datetime.now()
start_date = end_date - relativedelta(weeks=6) - relativedelta(days=1)
end_date_formatted = str(end_date).split(" ")[0]
start_date_formatted = str(start_date).split(" ")[0]

data = yf.download("BMW.DE", start=start_date_formatted, end=end_date_formatted)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#Construct an array of only the data we care about (yesterday, 1wk ago, 2wk ago, 3wk ago, etc up to 6wk)
target_date = end_date - relativedelta(weeks=6) - relativedelta(days=1)
target_date_formatted = str(target_date).split(" ")[0]

data.loc[target_date_formatted]

#An array to hold our closing values (from oldest to newest)
closing_values = []

while target_date <= end_date:
    target_row = data.loc[target_date_formatted]
    closing_values.append(target_row['Close'])
    target_date = target_date + relativedelta(weeks=1)
    target_date_formatted = str(target_date).split(" ")[0]
    
closing_values
# Out:
# [89.66000366210938,
#  95.30000305175781,
#  95.37999725341797,
#  88.0199966430664,
#  73.0999984741211,
#  72.41999816894531,
#  75.9000015258789]

# %%
#Okay.  We've proven we can get the stock prices.  Now let's prove we can grab the sentences for our sentiment score.
import requests
from bs4 import BeautifulSoup

URL = "https://finance.yahoo.com/quote/TSLA"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")
results = soup.find(id="quoteNewsStream-0-Stream-Proxy")
results

news_elements = results.find_all("li", class_="js-stream-content Pos(r)")
for news_element in news_elements:
    title_element = news_element.find("h3")
    subtitle_element = news_element.find("p")
    print(title_element.text)
    print(subtitle_element.text)
# Out:
# Electric vehicles: ‘We’ve seen a fairly steep rise’ in searches, analyst says
# Jessica Caldwell, executive director of insights at Edmunds, explains how more consumers are turning to electric vehicles.
# Elon Musk Has Billions, but Still Took Out Mortgages. Here's Why
# Elon Musk has founded Tesla, SpaceX, and a number of other companies.  In fact, Musk reportedly took out a combined total of $61 million in mortgages in 2018 for several properties in Bel Air and the Bay Area.  This included $50 million in new mortgage debt, as well as a refinance loan that he used to repay a mortgage that he had used to purchase a property in 2017.
# Dow Jones Futures: 2022's First Real Market Rally Gains Steam; Five Stocks Flash Buy Signals
# The market rally continues to gain steam, with Nvidia among stocks flashing buy signals. Time to go shopping, but don't go on a buying frenzy.
# Tesla Stock Vs. BYD Stock: Tesla Berlin Nears Milestone As EV Rival BYD Sets Huge Target
# Tesla stock vs. BYD stock: China's BYD is gaining ground on fast-growing Tesla. Here's a look at the EV giants' fundamentals and technicals.
# Tesla Clears a Big Obstacle for the Model 3 and Model Y
# Tesla's  bad week is ending on a positive note.  Earlier this week, Tesla announced price increases across its entire range of vehicles.  Inflation is driving up the price of its entire fleet, but the price of the Model 3 may be the most concerning for Tesla as that base model is supposed to be the affordable one.
# These Are The 5 Best EV Stocks To Buy And Watch Now
# EV stocks have multiplied in Tesla’s wake and as electric cars look to go mainstream. Here are the top-rated electric vehicle makers.
# Tesla CEO Elon Musk Is Working on Master Plan 3. The Stock Is Jumping.
# A Thursday tweet from  Tesla  CEO Elon Musk seems to be helping the stock.  All it says is “working on Master Plan Part 3,” but people who follow the electric-vehicle company know exactly what Musk is talking about.  Part 3 of the master plan would follow Part Deux, published in 2016, and Part 1, written by Musk in 2006.
# Can Rivian Replicate Tesla's Magic and Turn Things Around?
# Rivian's share price has fallen sharply, and after walking back an ill-advised price increase, the EV maker has a tough slog ahead.
# A Key GM EV Rivaling Rivian, Ford and Tesla Hits a Speed Bump
# Detroit giant GM is in full transition to electric vehicles. One of its key offerings hit a speed bump.

# %%
#There you have it!  We've proven we can get all the data we need to run this network.  All that's left is to run the sentiments
#through a network trained on https://www.kaggle.com/datasets/sbhatti/financial-sentiment-analysis and add the sentiment score,
#then construct the final dataframe and train a NN on it!
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import requests
from bs4 import BeautifulSoup

df = pd.read_csv("Largest automakers by market capitalization.csv")

df = df.drop(columns=['price (USD)','Rank'])
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
cols
df = df[cols]

sentiments = []
six_weeks_ago = []
five_weeks_ago = []
four_weeks_ago = []
three_weeks_ago = []
two_weeks_ago = []
one_week_ago = []
yesterday = []

#We only care about data from the last two months
end_date = datetime.now()
start_date = end_date - relativedelta(weeks=6) - relativedelta(days=1)
end_date_formatted = str(end_date).split(" ")[0]
start_date_formatted = str(start_date).split(" ")[0]

for symbol in df['Symbol'].values:
    print(symbol)

    stock_url = "https://finance.yahoo.com/quote/" + symbol

    page = requests.get(stock_url)

    soup = BeautifulSoup(page.content, "html.parser")
    results = soup.find(id="quoteNewsStream-0-Stream-Proxy")
    
    if results is None:
        results = soup.find(id="quoteNewsStream-0-Stream-Proxy")
        sentiments.append("No data!")
    else:
        sentiment_list = []

        news_elements = results.find_all("li", class_="js-stream-content Pos(r)")
        for news_element in news_elements:
            title_element = news_element.find("h3")
            subtitle_element = news_element.find("p")
            sentiment_list.append(title_element.text)
            sentiment_list.append(subtitle_element.text)
        
        sentiments.append(sentiment_list)

    data = yf.download(symbol, start=start_date_formatted, end=end_date_formatted)
    target_date = start_date
    target_date_formatted = str(target_date).split(" ")[0]

    #An array to hold our closing values (from oldest to newest)
    closing_values = []
    
    #print(data)
    #break
        
    while target_date <= end_date:
            try:
                data.loc[target_date_formatted]
            except:
                print(f"Error on symbol {symbol} for {target_date_formatted}")
                closing_values.append('error')
                
            else:
                target_row = data.loc[target_date_formatted]
                closing_values.append(target_row['Close'])
            target_date = target_date + relativedelta(weeks=1)
            target_date_formatted = str(target_date).split(" ")[0]
            
    six_weeks_ago.append(closing_values[0])
    five_weeks_ago.append(closing_values[1])
    four_weeks_ago.append(closing_values[2])
    three_weeks_ago.append(closing_values[3])
    two_weeks_ago.append(closing_values[4])
    one_week_ago.append(closing_values[5])
    yesterday.append(closing_values[6])

df['Stock Price (6wk ago),'] = six_weeks_ago
df['Stock Price (5wk ago),'] = five_weeks_ago
df['Stock Price (4wk ago),'] = four_weeks_ago
df['Stock Price (3wk ago),'] = three_weeks_ago
df['Stock Price (2wk ago),'] = two_weeks_ago
df['Stock Price (1wk ago),'] = one_week_ago
df['Stock Price (0wk ago),'] = yesterday
df['Sentiments'] = sentiments

cols = df.columns.tolist()
last = cols[-1:]
cols = cols[0:3] + last + cols[3:11]
df = df[cols]

file_name = "FinalProjectData_" + end_date_formatted + ".csv"
df.to_csv(file_name,index=False)
# Out:
# TSLA
# [*********************100%***********************]  1 of 1 completed
# Error on symbol TSLA for 2022-02-21
# TM
# [*********************100%***********************]  1 of 1 completed
# Error on symbol TM for 2022-02-21
# VOW3.DE
# [*********************100%***********************]  1 of 1 completed
# 002594.SZ
# [*********************100%***********************]  1 of 1 completed
# DAI.DE
# [*********************100%***********************]  1 of 1 completed
# GM
# [*********************100%***********************]  1 of 1 completed
# Error on symbol GM for 2022-02-21
# F
# [*********************100%***********************]  1 of 1 completed
# Error on symbol F for 2022-02-21
# BMW.DE
# [*********************100%***********************]  1 of 1 completed
# STLA
# [*********************100%***********************]  1 of 1 completed
# Error on symbol STLA for 2022-02-21
# HMC
# [*********************100%***********************]  1 of 1 completed
# Error on symbol HMC for 2022-02-21
# RIVN
# [*********************100%***********************]  1 of 1 completed
# Error on symbol RIVN for 2022-02-21
# 601633.SS
# [*********************100%***********************]  1 of 1 completed
# LCID
# [*********************100%***********************]  1 of 1 completed
# Error on symbol LCID for 2022-02-21
# RACE
# [*********************100%***********************]  1 of 1 completed
# Error on symbol RACE for 2022-02-21
# NIO
# [*********************100%***********************]  1 of 1 completed
# Error on symbol NIO for 2022-02-21
# HYMTF
# [*********************100%***********************]  1 of 1 completed
# Error on symbol HYMTF for 2022-02-21
# 600104.SS
# [*********************100%***********************]  1 of 1 completed
# MARUTI.NS
# [*********************100%***********************]  1 of 1 completed
# XPEV
# [*********************100%***********************]  1 of 1 completed
# Error on symbol XPEV for 2022-02-21
# LI
# [*********************100%***********************]  1 of 1 completed
# Error on symbol LI for 2022-02-21
# 000270.KS
# [*********************100%***********************]  1 of 1 completed
# TTM
# [*********************100%***********************]  1 of 1 completed
# Error on symbol TTM for 2022-02-21
# VOLCAR-B.ST
# [*********************100%***********************]  1 of 1 completed
# 0175.HK
# [*********************100%***********************]  1 of 1 completed
# 7201.T
# [*********************100%***********************]  1 of 1 completed
# Error on symbol 7201.T for 2022-03-21
# 7269.T
# [*********************100%***********************]  1 of 1 completed
# Error on symbol 7269.T for 2022-03-21
# M&M.NS
# [*********************100%***********************]  1 of 1 completed
# 000625.SZ
# [*********************100%***********************]  1 of 1 completed
# 7270.T
# [*********************100%***********************]  1 of 1 completed
# Error on symbol 7270.T for 2022-03-21
# 2207.TW
# [*********************100%***********************]  1 of 1 completed
# Error on symbol 2207.TW for 2022-02-28
# RNSDF
# [*********************100%***********************]  1 of 1 completed
# Error on symbol RNSDF for 2022-02-21
# 7202.T
# [*********************100%***********************]  1 of 1 completed
# Error on symbol 7202.T for 2022-03-21
# 0489.HK
# [*********************100%***********************]  1 of 1 completed
# PII
# [*********************100%***********************]  1 of 1 completed
# Error on symbol PII for 2022-02-21
# 000800.SZ
# [*********************100%***********************]  1 of 1 completed
# 7261.T
# [*********************100%***********************]  1 of 1 completed
# Error on symbol 7261.T for 2022-03-21
# FSR
# [*********************100%***********************]  1 of 1 completed
# Error on symbol FSR for 2022-02-21
# NKLA
# [*********************100%***********************]  1 of 1 completed
# Error on symbol NKLA for 2022-02-21
# ARVL
# [*********************100%***********************]  1 of 1 completed
# Error on symbol ARVL for 2022-02-21
# A5SA.F
# [*********************100%***********************]  1 of 1 completed
# GOEV
# [*********************100%***********************]  1 of 1 completed
# Error on symbol GOEV for 2022-02-21
# REE
# [*********************100%***********************]  1 of 1 completed
# Error on symbol REE for 2022-02-21
# RIDE
# [*********************100%***********************]  1 of 1 completed
# Error on symbol RIDE for 2022-02-21
# SEV
# [*********************100%***********************]  1 of 1 completed
# Error on symbol SEV for 2022-02-21
# CENN
# [*********************100%***********************]  1 of 1 completed
# Error on symbol CENN for 2022-02-21
# SOLO
# [*********************100%***********************]  1 of 1 completed
# Error on symbol SOLO for 2022-02-21
# FUV
# [*********************100%***********************]  1 of 1 completed
# Error on symbol FUV for 2022-02-21

# %%
df = pd.read_csv(file_name)
df
# Out:
#            country                     Name       Symbol  \
# 0    United States                    Tesla         TSLA
# 1            Japan                   Toyota           TM
# 2          Germany               Volkswagen      VOW3.DE
# 3            China                      BYD    002594.SZ
# 4          Germany                  Daimler       DAI.DE
# 5    United States           General Motors           GM
# 6    United States                     Ford            F
# 7          Germany                      BMW       BMW.DE
# 8      Netherlands               Stellantis         STLA
# 9            Japan                    Honda          HMC
# 10   United States                   Rivian         RIVN
# 11           China        Great Wall Motors    601633.SS
# 12   United States             Lucid Motors         LCID
# 13           Italy                  Ferrari         RACE
# 14           China                      NIO          NIO
# 15     South Korea                  Hyundai        HYMTF
# 16           China               SAIC Motor    600104.SS
# 17           India      Maruti Suzuki India    MARUTI.NS
# 18           China                    XPeng         XPEV
# 19           China                  Li Auto           LI
# 20     South Korea                      Kia    000270.KS
# 21           India              Tata Motors          TTM
# 22          Sweden                Volvo Car  VOLCAR-B.ST
# 23           China                    Geely      0175.HK
# 24           Japan                   Nissan       7201.T
# 25           Japan             Suzuki Motor       7269.T
# 26           India  Mahindra &amp; Mahindra       M&M.NS
# 27           China        Chongqing Changan    000625.SZ
# 28           Japan                   Subaru       7270.T
# 29          Taiwan              Hotai Motor      2207.TW
# 30          France                  Renault        RNSDF
# 31           Japan                    Isuzu       7202.T
# 32           China           Dongfeng Motor      0489.HK
# 33   United States                  Polaris          PII
# 34           China                  FAW Car    000800.SZ
# 35           Japan                    Mazda       7261.T
# 36   United States                   Fisker          FSR
# 37   United States                   Nikola         NKLA
# 38  United Kingdom                  Arrival         ARVL
# 39  United Kingdom             Aston Martin       A5SA.F
# 40   United States                    Canoo         GOEV
# 41          Israel           REE Automotive          REE
# 42   United States         Lordstown Motors         RIDE
# 43         Germany                     Sono          SEV
# 44   United States   Cenntro Electric Group         CENN
# 45          Canada        Electra Meccanica         SOLO
# 46   United States                 Arcimoto          FUV
#
#                                            Sentiments     marketcap  \
# 0   ['Tesla opens first European gigafactory in Be...  911205269504
# 1   ['Toyota Pauses Production. Covid-19, Not Chip...  274258280448
# 2   ['U.S. companies pull back from business deali...  124395549741
# 3                                            No data!  107779133682
# 4                                            No data!   85824249620
# 5   ['Super luxury brands like Lamborghini and Ben...   73682640896
# 6   ['Super luxury brands like Lamborghini and Ben...   71636033536
# 7                                            No data!   66793934199
# 8   ['Maserati unveils new SUV Grecale, full elect...   58517344256
# 9   ["Volkswagen exec on the electric VW bus: 'I’v...   51654283264
# 10  ['Electric vehicles: Cadillac kicks of Lyriq p...   51555225600
# 11                                           No data!   46988271198
# 12  ["Volkswagen exec on the electric VW bus: 'I’v...   44402597888
# 13  ['Italy set to curb use of Russian anti-virus ...   41415847936
# 14  ['Super luxury brands like Lamborghini and Ben...   38157774848
# 15  ['Hyundai IONIQ 5 Named 2022 Hispanic Motor Pr...   35301515264
# 16                                           No data!   35013982320
# 17                                           No data!   34667047519
# 18  ['Tesla Stock Vs. BYD Stock: Tesla Berlin Deli...   31566131200
# 19  ['Tesla Stock Vs. BYD Stock: Tesla Berlin Deli...   29570781184
# 20                                           No data!   26362709008
# 21  ['Jaguar Land Rover suspends sales to Russia',...   25118961664
# 22                                           No data!   22117588979
# 23  ['Polestar EVs Are Too Niche for Long-Term GGP...   21500620917
# 24                                           No data!   20143703912
# 25                                           No data!   20139874949
# 26                                           No data!   13776047805
# 27                                           No data!   13665733502
# 28                                           No data!   13337584364
# 29                                           No data!   11950329018
# 30                                           No data!   11810082816
# 31                                           No data!    9415990164
# 32                                           No data!    7905514243
# 33  ['Indian Motorcycle Celebrates Its Flat Track ...    7063361536
# 34                                           No data!    7036322814
# 35                                           No data!    4902781920
# 36  ['Why There May Not Be a Happy Ending in Skill...    3335132672
# 37  ['Nikola (NKLA) Dips More Than Broader Markets...    3063844096
# 38  ['British electric vehicle manufacturer postpo...    2393507072
# 39                                           No data!    1780768047
# 40  ['EV Roundup: Q4 Earnings Snapshots of RIDE, L...    1396880512
# 41  ['E-Tech Resources Inc. Announces Final Assay ...     827733568
# 42  ["Volkswagen exec on the electric VW bus: 'I’v...     572848384
# 43  ['Sono Motors Enters Series-Validation Phase',...     407959200
# 44  ['Cenntro Electric Acquires Majority Interest ...     404946784
# 45  ['ElectraMeccanica Announces New Global Corpor...     239938144
# 46  ['3 Well-Priced, Most-Shorted Stocks to Buy', ...     216942928
#
#     Stock Price (6wk ago),  Stock Price (5wk ago), Stock Price (4wk ago),  \
# 0               907.340027              875.760010                  error
# 1               197.240005              188.970001                  error
# 2               175.940002              182.699997     174.97999572753906
# 3               244.399994              231.979996     241.88999938964844
# 4                67.559998               74.309998      74.02999877929688
# 5                50.709999               48.400002                  error
# 6                17.889999               17.459999                  error
# 7                89.860001               92.589996      92.29000091552734
# 8                18.680000               18.400000                  error
# 9                29.549999               30.660000                  error
# 10               58.360001               62.650002                  error
# 11               41.099998               38.099998     38.119998931884766
# 12               26.969999               27.440001                  error
# 13              225.520004              218.210007                  error
# 14               23.990000               23.790001                  error
# 15               39.130001               39.000000                  error
# 16               18.930000               18.799999     18.829999923706055
# 17             8511.650391             8366.400391        8612.7001953125
# 18               36.860001               37.009998                  error
# 19               28.629999               28.480000                  error
# 20            78200.000000            77000.000000                78700.0
# 21               32.799999               31.110001                  error
# 22               67.820000               69.720001     62.540000915527344
# 23               17.240000               16.420000     16.360000610351562
# 24              598.900024              614.500000      598.0999755859375
# 25             4803.000000             4814.000000                 4864.0
# 26              829.500000              825.049988      841.0999755859375
# 27               12.980000               12.470000     13.079999923706055
# 28             2012.500000             1967.500000                 1975.5
# 29              609.000000              631.000000                  643.0
# 30               40.700001               39.717999                  error
# 31             1491.000000             1536.000000                 1638.0
# 32                6.970000                7.100000      7.179999828338623
# 33              116.400002              118.760002                  error
# 34                9.520000                9.710000        9.6899995803833
# 35              882.000000              894.000000                  931.0
# 36               11.240000               11.650000                  error
# 37                7.530000                8.020000                  error
# 38                3.760000                3.760000                  error
# 39               13.360000               13.800000                   13.0
# 40                5.850000                5.950000                  error
# 41                3.600000                3.310000                  error
# 42                2.980000                3.070000                  error
# 43                5.660000                6.030000                  error
# 44                1.550000                1.370000                  error
# 45                2.050000                2.010000                  error
# 46                5.760000                5.450000                  error
#
#    Stock Price (3wk ago),  Stock Price (2wk ago),  Stock Price (1wk ago),  \
# 0       870.4299926757812              804.580017              766.369995
# 1       182.9499969482422              160.169998              161.089996
# 2       178.0399932861328              136.740005              150.000000
# 3      249.60000610351562              223.610001              219.000000
# 4       70.16999816894531               57.389999               60.759998
# 5      46.720001220703125               39.830002               40.830002
# 6      17.559999465942383               15.970000               15.740000
# 7       86.55999755859375               70.519997               74.430000
# 8      18.280000686645508               13.790000               15.160000
# 9      30.559999465942383               26.680000               26.660000
# 10      67.55999755859375               42.430000               35.830002
# 11       36.5099983215332               31.920000               28.370001
# 12     28.979999542236328               23.170000               21.549999
# 13     215.30999755859375              183.250000              192.929993
# 14      22.84000015258789               18.120001               14.100000
# 15     37.279998779296875               34.980000               34.830002
# 16     18.110000610351562               18.320000               17.799999
# 17         8314.150390625             6769.049805             7316.750000
# 18     36.369998931884766               27.209999               19.750000
# 19     30.450000762939453               25.700001               17.600000
# 20                73800.0            71100.000000            68800.000000
# 21     30.290000915527344               24.750000               25.770000
# 22      66.44000244140625               56.439999               55.419998
# 23     14.420000076293945               12.100000               10.560000
# 24      545.2999877929688              464.399994              464.799988
# 25                 4573.0             3835.000000             3786.000000
# 26      790.8499755859375              690.549988              743.200012
# 27       12.9399995803833               12.190000               11.300000
# 28                 1893.5             1743.500000             1763.500000
# 29                  error              594.000000              581.000000
# 30                 32.625               23.799999               24.820000
# 31                 1557.0             1384.000000             1501.000000
# 32      6.710000038146973                6.150000                5.600000
# 33     121.51000213623047              109.400002              104.389999
# 34      9.289999961853027                9.000000                8.360000
# 35                  856.0              747.000000              794.000000
# 36     12.199999809265137               10.650000               10.300000
# 37      7.900000095367432                6.640000                6.870000
# 38      3.490000009536743                3.140000                3.060000
# 39     12.142000198364258                9.464000               10.590000
# 40      5.739999771118164                4.950000                5.180000
# 41      2.609999895095825                2.210000                1.890000
# 42      2.569999933242798                2.100000                2.050000
# 43      5.170000076293945                4.035000                4.100000
# 44      1.440000057220459                1.450000                1.220000
# 45      1.940000057220459                1.850000                1.700000
# 46      5.880000114440918                7.140000                5.890000
#
#    Stock Price (0wk ago),
# 0       921.1599731445312
# 1       171.8000030517578
# 2      153.75999450683594
# 3       245.3800048828125
# 4       63.31999969482422
# 5       43.61000061035156
# 6      16.479999542236328
# 7       77.44000244140625
# 8      16.190000534057617
# 9      28.229999542236328
# 10     43.560001373291016
# 11     28.510000228881836
# 12     25.389999389648438
# 13      207.5399932861328
# 14     20.260000228881836
# 15      34.84000015258789
# 16     17.190000534057617
# 17        7705.5498046875
# 18      27.31999969482422
# 19     26.329999923706055
# 20                72000.0
# 21      27.81999969482422
# 22      56.08000183105469
# 23     11.420000076293945
# 24                  error
# 25                  error
# 26                  783.5
# 27     11.430000305175781
# 28                  error
# 29                  582.0
# 30      25.15999984741211
# 31                  error
# 32      5.900000095367432
# 33      108.2300033569336
# 34      8.210000038146973
# 35                  error
# 36     12.170000076293945
# 37      8.850000381469727
# 38     3.5899999141693115
# 39     11.142000198364258
# 40      5.869999885559082
# 41                   2.25
# 42      2.759999990463257
# 43       5.46999979019165
# 44     2.2750000953674316
# 45      2.380000114440918
# 46      6.940000057220459

# %%
#!pip install yfinance
#!pip install requests
#!pip install beautifulsoup4

# %%
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

#We only care about data from the last two months
end_date = datetime.now()
start_date = end_date - relativedelta(weeks=6) - relativedelta(days=1)
end_date_formatted = str(end_date).split(" ")[0]
start_date_formatted = str(start_date).split(" ")[0]

data = yf.download("BMW.DE", start=start_date_formatted, end=end_date_formatted)

data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-03-11  72.919998  75.459999  72.000000  72.419998  72.419998  2873113
# 2022-03-14  74.639999  76.370003  73.980003  74.430000  74.430000  2514991
# 2022-03-15  73.629997  75.779999  71.699997  75.320000  75.320000  2601157
# 2022-03-16  77.540001  79.279999  76.180000  78.400002  78.400002  3188590
# 2022-03-17  79.339996  79.400002  75.510002  76.669998  76.669998  2207957
# 2022-03-18  76.199997  76.660004  74.750000  75.900002  75.900002  4736344
# 2022-03-21  76.239998  77.970001  75.739998  77.440002  77.440002  1686583
# 2022-03-22  78.349998  79.760002  77.349998  79.059998  79.059998  1732509
# 2022-03-23  80.339996  80.800003  77.849998  78.260002  78.260002  1942435
# 2022-03-24  78.309998  79.010002  77.320000  78.470001  78.470001  1529917
# 2022-03-25  78.000000  78.459999  77.199997  77.889999  77.889999  1514673
# 2022-03-28  78.099998  79.949997  78.040001  78.239998  78.239998  1109020
# 2022-03-29  79.830002  83.470001  79.180000  82.629997  82.629997  1967947
# 2022-03-30  81.699997  82.160004  80.120003  80.260002  80.260002  1492559
# 2022-03-31  81.300003  81.709999  78.410004  78.599998  78.599998  1468453
# 2022-04-01  78.510002  80.129997  78.339996  79.000000  79.000000  1064970
# 2022-04-04  79.599998  80.169998  77.970001  79.849998  79.849998  1100335
# 2022-04-05  79.739998  80.620003  77.790001  78.180000  78.180000  1523273
# 2022-04-06  77.879997  78.059998  74.849998  76.300003  76.300003  1651158
# 2022-04-07  76.540001  77.919998  75.669998  75.669998  75.669998  1345977
# 2022-04-08  77.199997  77.730003  76.260002  77.000000  77.000000  1113844
# 2022-04-11  76.099998  76.930000  75.110001  75.989998  75.989998  1246230
# 2022-04-12  74.849998  76.970001  74.279999  76.089996  76.089996  1364957
# 2022-04-13  76.000000  76.300003  75.040001  76.250000  76.250000  1062598
# 2022-04-14  76.360001  77.160004  75.820000  76.239998  76.239998  1418145
# 2022-04-19  76.459999  78.250000  75.889999  78.019997  78.019997  1477517
# 2022-04-20  78.540001  80.190002  78.089996  79.199997  79.199997  1100786
# 2022-04-21  79.199997  79.199997  79.199997  79.199997  79.199997        0
# 2022-04-22  79.199997  79.199997  79.199997  79.199997  79.199997        0

# %%
#Construct an array of only the data we care about (yesterday, 1wk ago, 2wk ago, 3wk ago, etc up to 6wk)
target_date = end_date - relativedelta(weeks=6) - relativedelta(days=1)
target_date_formatted = str(target_date).split(" ")[0]

data.loc[target_date_formatted]

#An array to hold our closing values (from oldest to newest)
closing_values = []

while target_date <= end_date:
    target_row = data.loc[target_date_formatted]
    closing_values.append(target_row['Close'])
    target_date = target_date + relativedelta(weeks=1)
    target_date_formatted = str(target_date).split(" ")[0]
    
closing_values
# Out:
# [89.66000366210938,
#  95.30000305175781,
#  95.37999725341797,
#  88.0199966430664,
#  73.0999984741211,
#  72.41999816894531,
#  75.9000015258789]

# %%
#Okay.  We've proven we can get the stock prices.  Now let's prove we can grab the sentences for our sentiment score.
import requests
from bs4 import BeautifulSoup

URL = "https://finance.yahoo.com/quote/TSLA"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")
results = soup.find(id="quoteNewsStream-0-Stream-Proxy")
results

news_elements = results.find_all("li", class_="js-stream-content Pos(r)")
for news_element in news_elements:
    title_element = news_element.find("h3")
    subtitle_element = news_element.find("p")
    print(title_element.text)
    print(subtitle_element.text)
# Out:
# Electric vehicles: ‘We’ve seen a fairly steep rise’ in searches, analyst says
# Jessica Caldwell, executive director of insights at Edmunds, explains how more consumers are turning to electric vehicles.
# Elon Musk Has Billions, but Still Took Out Mortgages. Here's Why
# Elon Musk has founded Tesla, SpaceX, and a number of other companies.  In fact, Musk reportedly took out a combined total of $61 million in mortgages in 2018 for several properties in Bel Air and the Bay Area.  This included $50 million in new mortgage debt, as well as a refinance loan that he used to repay a mortgage that he had used to purchase a property in 2017.
# Dow Jones Futures: 2022's First Real Market Rally Gains Steam; Five Stocks Flash Buy Signals
# The market rally continues to gain steam, with Nvidia among stocks flashing buy signals. Time to go shopping, but don't go on a buying frenzy.
# Tesla Stock Vs. BYD Stock: Tesla Berlin Nears Milestone As EV Rival BYD Sets Huge Target
# Tesla stock vs. BYD stock: China's BYD is gaining ground on fast-growing Tesla. Here's a look at the EV giants' fundamentals and technicals.
# Tesla Clears a Big Obstacle for the Model 3 and Model Y
# Tesla's  bad week is ending on a positive note.  Earlier this week, Tesla announced price increases across its entire range of vehicles.  Inflation is driving up the price of its entire fleet, but the price of the Model 3 may be the most concerning for Tesla as that base model is supposed to be the affordable one.
# These Are The 5 Best EV Stocks To Buy And Watch Now
# EV stocks have multiplied in Tesla’s wake and as electric cars look to go mainstream. Here are the top-rated electric vehicle makers.
# Tesla CEO Elon Musk Is Working on Master Plan 3. The Stock Is Jumping.
# A Thursday tweet from  Tesla  CEO Elon Musk seems to be helping the stock.  All it says is “working on Master Plan Part 3,” but people who follow the electric-vehicle company know exactly what Musk is talking about.  Part 3 of the master plan would follow Part Deux, published in 2016, and Part 1, written by Musk in 2006.
# Can Rivian Replicate Tesla's Magic and Turn Things Around?
# Rivian's share price has fallen sharply, and after walking back an ill-advised price increase, the EV maker has a tough slog ahead.
# A Key GM EV Rivaling Rivian, Ford and Tesla Hits a Speed Bump
# Detroit giant GM is in full transition to electric vehicles. One of its key offerings hit a speed bump.

# %%
#There you have it!  We've proven we can get all the data we need to run this network.  All that's left is to run the sentiments
#through a network trained on https://www.kaggle.com/datasets/sbhatti/financial-sentiment-analysis and add the sentiment score,
#then construct the final dataframe and train a NN on it!
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import requests
from bs4 import BeautifulSoup

df = pd.read_csv("Largest automakers by market capitalization.csv")

df = df.drop(columns=['price (USD)','Rank'])
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
cols
df = df[cols]

sentiments = []
six_weeks_ago = []
five_weeks_ago = []
four_weeks_ago = []
three_weeks_ago = []
two_weeks_ago = []
one_week_ago = []
yesterday = []

#We only care about data from the last two months
end_date = datetime.now()
start_date = end_date - relativedelta(weeks=6) - relativedelta(days=1)
end_date_formatted = str(end_date).split(" ")[0]
start_date_formatted = str(start_date).split(" ")[0]

for symbol in df['Symbol'].values:
    print(symbol)

    stock_url = "https://finance.yahoo.com/quote/" + symbol

    page = requests.get(stock_url)

    soup = BeautifulSoup(page.content, "html.parser")
    results = soup.find(id="quoteNewsStream-0-Stream-Proxy")
    
    if results is None:
        results = soup.find(id="quoteNewsStream-0-Stream-Proxy")
        sentiments.append("No data!")
    else:
        sentiment_list = []

        news_elements = results.find_all("li", class_="js-stream-content Pos(r)")
        for news_element in news_elements:
            title_element = news_element.find("h3")
            subtitle_element = news_element.find("p")
            sentiment_list.append(title_element.text)
            sentiment_list.append(subtitle_element.text)
        
        sentiments.append(sentiment_list)

    data = yf.download(symbol, start=start_date_formatted, end=end_date_formatted)
    target_date = start_date
    target_date_formatted = str(target_date).split(" ")[0]

    #An array to hold our closing values (from oldest to newest)
    closing_values = []
    
    #print(data)
    #break
        
    while target_date <= end_date:
            try:
                data.loc[target_date_formatted]
            except:
                print(f"Error on symbol {symbol} for {target_date_formatted}")
                closing_values.append('error')
                
            else:
                target_row = data.loc[target_date_formatted]
                closing_values.append(target_row['Close'])
            target_date = target_date + relativedelta(weeks=1)
            target_date_formatted = str(target_date).split(" ")[0]
            
    six_weeks_ago.append(closing_values[0])
    five_weeks_ago.append(closing_values[1])
    four_weeks_ago.append(closing_values[2])
    three_weeks_ago.append(closing_values[3])
    two_weeks_ago.append(closing_values[4])
    one_week_ago.append(closing_values[5])
    yesterday.append(closing_values[6])

df['Stock Price (6wk ago),'] = six_weeks_ago
df['Stock Price (5wk ago),'] = five_weeks_ago
df['Stock Price (4wk ago),'] = four_weeks_ago
df['Stock Price (3wk ago),'] = three_weeks_ago
df['Stock Price (2wk ago),'] = two_weeks_ago
df['Stock Price (1wk ago),'] = one_week_ago
df['Stock Price (0wk ago),'] = yesterday
df['Sentiments'] = sentiments

cols = df.columns.tolist()
last = cols[-1:]
cols = cols[0:3] + last + cols[3:11]
df = df[cols]

file_name = "FinalProjectData_" + end_date_formatted + ".csv"
df.to_csv(file_name,index=False)
# Out:
# TSLA
# [*********************100%***********************]  1 of 1 completed
# Error on symbol TSLA for 2022-04-15
# TM
# [*********************100%***********************]  1 of 1 completed
# Error on symbol TM for 2022-04-15
# VOW3.DE
# [*********************100%***********************]  1 of 1 completed
# Error on symbol VOW3.DE for 2022-04-15
# 002594.SZ
# [*********************100%***********************]  1 of 1 completed
# DAI.DE
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DAI.DE: No data found, symbol may be delisted
# Error on symbol DAI.DE for 2022-03-11
# Error on symbol DAI.DE for 2022-03-18
# Error on symbol DAI.DE for 2022-03-25
# Error on symbol DAI.DE for 2022-04-01
# Error on symbol DAI.DE for 2022-04-08
# Error on symbol DAI.DE for 2022-04-15
# Error on symbol DAI.DE for 2022-04-22
# GM
# [*********************100%***********************]  1 of 1 completed
# Error on symbol GM for 2022-04-15
# F
# [*********************100%***********************]  1 of 1 completed
# Error on symbol F for 2022-04-15
# BMW.DE
# [*********************100%***********************]  1 of 1 completed
# Error on symbol BMW.DE for 2022-04-15
# STLA
# [*********************100%***********************]  1 of 1 completed
# Error on symbol STLA for 2022-04-15
# HMC
# [*********************100%***********************]  1 of 1 completed
# Error on symbol HMC for 2022-04-15
# RIVN
# [*********************100%***********************]  1 of 1 completed
# Error on symbol RIVN for 2022-04-15
# 601633.SS
# [*********************100%***********************]  1 of 1 completed
# LCID
# [*********************100%***********************]  1 of 1 completed
# Error on symbol LCID for 2022-04-15
# RACE
# [*********************100%***********************]  1 of 1 completed
# Error on symbol RACE for 2022-04-15
# NIO
# [*********************100%***********************]  1 of 1 completed
# Error on symbol NIO for 2022-04-15
# HYMTF
# [*********************100%***********************]  1 of 1 completed
# Error on symbol HYMTF for 2022-04-15
# 600104.SS
# [*********************100%***********************]  1 of 1 completed
# MARUTI.NS
# [*********************100%***********************]  1 of 1 completed
# Error on symbol MARUTI.NS for 2022-03-18
# Error on symbol MARUTI.NS for 2022-04-15
# XPEV
# [*********************100%***********************]  1 of 1 completed
# Error on symbol XPEV for 2022-04-15
# LI
# [*********************100%***********************]  1 of 1 completed
# Error on symbol LI for 2022-04-15
# 000270.KS
# [*********************100%***********************]  1 of 1 completed
# TTM
# [*********************100%***********************]  1 of 1 completed
# Error on symbol TTM for 2022-04-15
# VOLCAR-B.ST
# [*********************100%***********************]  1 of 1 completed
# Error on symbol VOLCAR-B.ST for 2022-04-15
# 0175.HK
# [*********************100%***********************]  1 of 1 completed
# Error on symbol 0175.HK for 2022-04-15
# 7201.T
# [*********************100%***********************]  1 of 1 completed
# 7269.T
# [*********************100%***********************]  1 of 1 completed
# M&M.NS
# [*********************100%***********************]  1 of 1 completed
# Error on symbol M&M.NS for 2022-03-18
# Error on symbol M&M.NS for 2022-04-15
# 000625.SZ
# [*********************100%***********************]  1 of 1 completed
# 7270.T
# [*********************100%***********************]  1 of 1 completed
# 2207.TW
# [*********************100%***********************]  1 of 1 completed
# RNSDF
# [*********************100%***********************]  1 of 1 completed
# Error on symbol RNSDF for 2022-04-15
# 7202.T
# [*********************100%***********************]  1 of 1 completed
# 0489.HK
# [*********************100%***********************]  1 of 1 completed
# Error on symbol 0489.HK for 2022-04-15
# PII
# [*********************100%***********************]  1 of 1 completed
# Error on symbol PII for 2022-04-15
# 000800.SZ
# [*********************100%***********************]  1 of 1 completed
# 7261.T
# [*********************100%***********************]  1 of 1 completed
# FSR
# [*********************100%***********************]  1 of 1 completed
# Error on symbol FSR for 2022-04-15
# NKLA
# [*********************100%***********************]  1 of 1 completed
# Error on symbol NKLA for 2022-04-15
# ARVL
# [*********************100%***********************]  1 of 1 completed
# Error on symbol ARVL for 2022-04-15
# A5SA.F
# [*********************100%***********************]  1 of 1 completed
# Error on symbol A5SA.F for 2022-04-15
# GOEV
# [*********************100%***********************]  1 of 1 completed
# Error on symbol GOEV for 2022-04-15
# REE
# [*********************100%***********************]  1 of 1 completed
# Error on symbol REE for 2022-04-15
# RIDE
# [*********************100%***********************]  1 of 1 completed
# Error on symbol RIDE for 2022-04-15
# SEV
# [*********************100%***********************]  1 of 1 completed
# Error on symbol SEV for 2022-04-15
# CENN
# [*********************100%***********************]  1 of 1 completed
# Error on symbol CENN for 2022-04-15
# SOLO
# [*********************100%***********************]  1 of 1 completed
# Error on symbol SOLO for 2022-04-15
# FUV
# [*********************100%***********************]  1 of 1 completed
# Error on symbol FUV for 2022-04-15

# %%
df = pd.read_csv(file_name)
df
# Out:
#            country                     Name       Symbol  \
# 0    United States                    Tesla         TSLA
# 1            Japan                   Toyota           TM
# 2          Germany               Volkswagen      VOW3.DE
# 3            China                      BYD    002594.SZ
# 4          Germany                  Daimler       DAI.DE
# 5    United States           General Motors           GM
# 6    United States                     Ford            F
# 7          Germany                      BMW       BMW.DE
# 8      Netherlands               Stellantis         STLA
# 9            Japan                    Honda          HMC
# 10   United States                   Rivian         RIVN
# 11           China        Great Wall Motors    601633.SS
# 12   United States             Lucid Motors         LCID
# 13           Italy                  Ferrari         RACE
# 14           China                      NIO          NIO
# 15     South Korea                  Hyundai        HYMTF
# 16           China               SAIC Motor    600104.SS
# 17           India      Maruti Suzuki India    MARUTI.NS
# 18           China                    XPeng         XPEV
# 19           China                  Li Auto           LI
# 20     South Korea                      Kia    000270.KS
# 21           India              Tata Motors          TTM
# 22          Sweden                Volvo Car  VOLCAR-B.ST
# 23           China                    Geely      0175.HK
# 24           Japan                   Nissan       7201.T
# 25           Japan             Suzuki Motor       7269.T
# 26           India  Mahindra &amp; Mahindra       M&M.NS
# 27           China        Chongqing Changan    000625.SZ
# 28           Japan                   Subaru       7270.T
# 29          Taiwan              Hotai Motor      2207.TW
# 30          France                  Renault        RNSDF
# 31           Japan                    Isuzu       7202.T
# 32           China           Dongfeng Motor      0489.HK
# 33   United States                  Polaris          PII
# 34           China                  FAW Car    000800.SZ
# 35           Japan                    Mazda       7261.T
# 36   United States                   Fisker          FSR
# 37   United States                   Nikola         NKLA
# 38  United Kingdom                  Arrival         ARVL
# 39  United Kingdom             Aston Martin       A5SA.F
# 40   United States                    Canoo         GOEV
# 41          Israel           REE Automotive          REE
# 42   United States         Lordstown Motors         RIDE
# 43         Germany                     Sono          SEV
# 44   United States   Cenntro Electric Group         CENN
# 45          Canada        Electra Meccanica         SOLO
# 46   United States                 Arcimoto          FUV
#
#                                            Sentiments     marketcap  \
# 0   ['Tesla earnings blow away expectations with r...  911205269504
# 1   ['Hyperspeed EV recruitment efforts offer tran...  274258280448
# 2                                            No data!  124395549741
# 3                                            No data!  107779133682
# 4                                            No data!   85824249620
# 5   ["NY Auto Show's top trends: Electric vehicles...   73682640896
# 6   ['Tech companies gear up to report earnings ne...   71636033536
# 7                                            No data!   66793934199
# 8   ['Stellantis Strengthens Hydrogen Fuel Cell Ve...   58517344256
# 9   ['GM, Honda Are Joining the Race for the Next ...   51654283264
# 10  ['Tesla Stock Vs. BYD Stock: Tesla Earnings Bo...   51555225600
# 11                                           No data!   46988271198
# 12  ['Bitcoin rallies after dip earlier in the wee...   44402597888
# 13  ['Ferrari N.v.: Periodic Report on the Buyback...   41415847936
# 14  ['Why Nio Stock Plunged 12% This Week, but Cou...   38157774848
# 15  ['Hyundai Motor America Reports Record-Breakin...   35301515264
# 16                                           No data!   35013982320
# 17                                           No data!   34667047519
# 18  ['5 Best Chinese Stocks To Buy And Watch: Covi...   31566131200
# 19  ['5 Best Chinese Stocks To Buy And Watch: Covi...   29570781184
# 20                                           No data!   26362709008
# 21  ["India's Tata Motors plans longer range EVs i...   25118961664
# 22                                           No data!   22117588979
# 23  ["(OFFICIAL)-Japan start-up to offer fleet ser...   21500620917
# 24                                           No data!   20143703912
# 25                                           No data!   20139874949
# 26                                           No data!   13776047805
# 27                                           No data!   13665733502
# 28                                           No data!   13337584364
# 29                                           No data!   11950329018
# 30                                           No data!   11810082816
# 31                                           No data!    9415990164
# 32                                           No data!    7905514243
# 33  ['Polaris Donates Nearly $120,000 to Off-Road ...    7063361536
# 34                                           No data!    7036322814
# 35                                           No data!    4902781920
# 36  ['Buy These 3 Electric Vehicle Stocks at Disco...    3335132672
# 37  ['Nikola to lose one board member', "Nikola Co...    3063844096
# 38  ['Arrival to Report First Quarter 2022 Financi...    2393507072
# 39                                           No data!    1780768047
# 40  ["Is Canoo Inc.'s (NASDAQ:GOEV) Shareholder Ow...    1396880512
# 41  ['Ree Automotive Appoints Josh Tech as Chief O...     827733568
# 42  ["Analyst on Tesla robotaxis: 'I will believe ...     572848384
# 43  ['Full Year 2021 Corporate Update:  Sono Motor...     407959200
# 44  ['Cenntro Electric Group to Host 2021 Year End...     404946784
# 45  ['ElectraMeccanica Appoints Automotive Veteran...     239938144
# 46  ['Arcimoto Vehicles Reclassified as Autocycles...     216942928
#
#    Stock Price (6wk ago), Stock Price (5wk ago), Stock Price (4wk ago),  \
# 0       795.3499755859375      905.3900146484375     1010.6400146484375
# 1      158.27000427246094      171.6999969482422     178.42999267578125
# 2       143.6999969482422      153.9199981689453     151.17999267578125
# 3      229.85000610351562                  234.5     235.30999755859375
# 4                   error                  error                  error
# 5        41.5099983215332      44.81999969482422     43.650001525878906
# 6      16.040000915527344     16.860000610351562     16.469999313354492
# 7       72.41999816894531       75.9000015258789      77.88999938964844
# 8       14.59000015258789     16.299999237060547     15.859999656677246
# 9      26.450000762939453      28.31999969482422     28.440000534057617
# 10      38.04999923706055     45.599998474121094      46.15999984741211
# 11     29.790000915527344     28.469999313354492     27.649999618530273
# 12     22.920000076293945     25.670000076293945      25.15999984741211
# 13      190.4499969482422     209.61000061035156     213.33999633789062
# 14      16.06999969482422     20.860000610351562      19.90999984741211
# 15     35.150001525878906                   36.0     34.880001068115234
# 16     17.950000762939453     17.469999313354492     16.979999542236328
# 17        7102.5498046875                  error        7415.4501953125
# 18      22.90999984741211     28.770000457763672     27.049999237060547
# 19     22.170000076293945     28.190000534057617     26.399999618530273
# 20                69600.0                72000.0                71600.0
# 21     26.200000762939453      28.59000015258789     28.399999618530273
# 22     55.900001525878906      56.65999984741211      57.65999984741211
# 23       11.4399995803833       11.9399995803833     11.579999923706055
# 24                  455.5      505.3999938964844                  530.5
# 25                 3732.0                 4062.0                 4200.0
# 26      734.7999877929688                  error                 764.75
# 27       11.4399995803833     11.399999618530273       11.1899995803833
# 28                 1734.0                 1830.5                 1938.0
# 29                  582.0                  569.0                  583.0
# 30     25.079999923706055      24.81999969482422     25.100000381469727
# 31                 1456.0                 1580.0                 1594.0
# 32      5.929999828338623      5.989999771118164      5.920000076293945
# 33     106.44000244140625     110.26000213623047                  106.5
# 34       8.59000015258789      8.260000228881836      8.199999809265137
# 35                  761.0                  849.0                  896.0
# 36     11.029999732971191     12.489999771118164     12.130000114440918
# 37      7.519999980926514      8.869999885559082     10.109999656677246
# 38      3.299999952316284     3.7300000190734863     3.7899999618530273
# 39     10.359999656677246      11.13599967956543       11.1899995803833
# 40      5.710000038146973      6.070000171661377      5.519999980926514
# 41     2.1600000858306885     2.2200000286102295     1.9800000190734863
# 42     2.1500000953674316      2.799999952316284      3.119999885559082
# 43      4.510000228881836      5.039999961853027      5.210000038146973
# 44     1.2799999713897705     1.7999999523162842      2.319999933242798
# 45     1.8600000143051147     2.2799999713897705      2.259999990463257
# 46      6.829999923706055      7.079999923706055      6.949999809265137
#
#    Stock Price (3wk ago), Stock Price (2wk ago), Stock Price (1wk ago),  \
# 0      1084.5899658203125      1025.489990234375                  error
# 1       180.3699951171875     170.77999877929688                  error
# 2       157.5800018310547      153.0399932861328                  error
# 3       235.9600067138672     243.97999572753906      236.1999969482422
# 4                   error                  error                  error
# 5      42.959999084472656     39.349998474121094                  error
# 6      16.649999618530273     15.050000190734863                  error
# 7                    79.0                   77.0                  error
# 8      16.350000381469727     14.850000381469727                  error
# 9      28.299999237060547     26.059999465942383                  error
# 10     46.439998626708984      38.79999923706055                  error
# 11     27.760000228881836      26.34000015258789      25.68000030517578
# 12     24.549999237060547     21.670000076293945                  error
# 13      221.0800018310547     219.50999450683594                  error
# 14      21.93000030517578                   20.0                  error
# 15                   34.5      34.91999816894531                  error
# 16     17.049999237060547     16.940000534057617     16.850000381469727
# 17        7700.0498046875        7557.9501953125                  error
# 18     29.190000534057617     27.190000534057617                  error
# 19     27.239999771118164     25.860000610351562                  error
# 20                74200.0                74900.0                76700.0
# 21     29.219999313354492     30.149999618530273                  error
# 22      70.04000091552734       69.5999984741211                  error
# 23     12.380000114440918                   12.0                  error
# 24                  540.0      508.6000061035156      510.6000061035156
# 25                 4158.0                 3884.0                 3888.0
# 26      826.5499877929688      857.4000244140625                  error
# 27     11.380000114440918     10.989999771118164     10.390000343322754
# 28                 1914.0                 1813.5                 1804.0
# 29                  593.0                  583.0                  578.0
# 30     27.218000411987305     27.218000411987305                  error
# 31                 1559.0                 1461.0                 1489.0
# 32      5.940000057220459      5.860000133514404                  error
# 33     106.44000244140625     104.55000305175781                  error
# 34        8.6899995803833        8.5600004196167      8.579999923706055
# 35                  911.0                  854.0                  878.0
# 36     13.020000457763672     12.479999542236328                  error
# 37     10.029999732971191      8.430000305175781                  error
# 38      3.700000047683716     3.1500000953674316                  error
# 39     11.800000190734863      10.46500015258789                  error
# 40      5.429999828338623                   5.25                  error
# 41     1.9199999570846558     1.9600000381469727                  error
# 42     3.2100000381469727     2.9000000953674316                  error
# 43       5.21999979019165      4.489999771118164                  error
# 44      2.109999895095825      1.909999966621399                  error
# 45      2.200000047683716     1.9700000286102295                  error
# 46      5.699999809265137      5.300000190734863                  error
#
#    Stock Price (0wk ago),
# 0      1005.0499877929688
# 1      169.52999877929688
# 2       152.5399932861328
# 3      235.39999389648438
# 4                   error
# 5       39.84000015258789
# 6      15.130000114440918
# 7       79.19999694824219
# 8      14.020000457763672
# 9       25.93000030517578
# 10      33.61000061035156
# 11     24.360000610351562
# 12     19.110000610351562
# 13      210.4600067138672
# 14      17.18000030517578
# 15      36.20000076293945
# 16     16.209999084472656
# 17                 7904.5
# 18       23.8700008392334
# 19     22.329999923706055
# 20                79800.0
# 21      28.09000015258789
# 22      68.91000366210938
# 23     11.600000381469727
# 24      536.9000244140625
# 25                 4071.0
# 26      920.6500244140625
# 27     10.350000381469727
# 28                 1944.0
# 29                  589.0
# 30     24.059999465942383
# 31                 1542.0
# 32      5.670000076293945
# 33     103.16000366210938
# 34      8.289999961853027
# 35                  924.0
# 36     11.010000228881836
# 37      7.679999828338623
# 38      2.450000047683716
# 39     10.295000076293945
# 40      4.949999809265137
# 41     2.0999999046325684
# 42      2.299999952316284
# 43      6.039999961853027
# 44     1.7000000476837158
# 45     1.8200000524520874
# 46     3.9200000762939453
